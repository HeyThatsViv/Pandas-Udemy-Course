# %% [markdown]
# ## importing csv files

# %%
with open('titanic.csv') as f:
    text = f.readlines()

# %%
text
# Out:
# ['survived,pclass,sex,age,sibsp,parch,fare,embarked,deck\n',
#  '0,3,male,22.0,1,0,7.25,S,\n',
#  '1,1,female,38.0,1,0,71.2833,C,C\n',
#  '1,3,female,26.0,0,0,7.925,S,\n',
#  '1,1,female,35.0,1,0,53.1,S,C\n',
#  '0,3,male,35.0,0,0,8.05,S,\n',
#  '0,3,male,,0,0,8.4583,Q,\n',
#  '0,1,male,54.0,0,0,51.8625,S,E\n',
#  '0,3,male,2.0,3,1,21.075,S,\n',
#  '1,3,female,27.0,0,2,11.1333,S,\n',
#  '1,2,female,14.0,1,0,30.0708,C,\n',
#  '1,3,female,4.0,1,1,16.7,S,G\n',
#  '1,1,female,58.0,0,0,26.55,S,C\n',
#  '0,3,male,20.0,0,0,8.05,S,\n',
#  '0,3,male,39.0,1,5,31.275,S,\n',
#  '0,3,female,14.0,0,0,7.8542,S,\n',
#  '1,2,female,55.0,0,0,16.0,S,\n',
#  '0,3,male,2.0,4,1,29.125,Q,\n',
#  '1,2,male,,0,0,13.0,S,\n',
#  '0,3,female,31.0,1,0,18.0,S,\n',
#  '1,3,female,,0,0,7.225,C,\n',
#  '0,2,male,35.0,0,0,26.0,S,\n',
#  '1,2,male,34.0,0,0,13.0,S,D\n',
#  '1,3,female,15.0,0,0,8.0292,Q,\n',
#  '1,1,male,28.0,0,0,35.5,S,A\n',
#  '0,3,female,8.0,3,1,21.075,S,\n',
#  '1,3,female,38.0,1,5,31.3875,S,\n',
# ...

# %%
len(text)
# Out:
# 892

# %%
print('hello world!')
# Out:
# hello world!

# %%
print('hello\n world!')
# Out:
# hello
#  world!

# %%
import pandas as pd

# %%
pd.read_csv('titanic.csv')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
pd.read_csv('titanic.csv', index_col='pclass')
# Out:
#         survived     sex   age  sibsp  parch     fare embarked deck
# pclass
# 3              0    male  22.0      1      0   7.2500        S  NaN
# 1              1  female  38.0      1      0  71.2833        C    C
# 3              1  female  26.0      0      0   7.9250        S  NaN
# 1              1  female  35.0      1      0  53.1000        S    C
# 3              0    male  35.0      0      0   8.0500        S  NaN
# ...          ...     ...   ...    ...    ...      ...      ...  ...
# 2              0    male  27.0      0      0  13.0000        S  NaN
# 1              1  female  19.0      0      0  30.0000        S    B
# 3              0  female   NaN      1      2  23.4500        S  NaN
# 1              1    male  26.0      0      0  30.0000        C    C
# 3              0    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 8 columns]

# %%
pd.read_csv('titanic.csv', header=None)
# Out:
#             0       1       2     3      4      5        6         7     8
# 0    survived  pclass     sex   age  sibsp  parch     fare  embarked  deck
# 1           0       3    male  22.0      1      0     7.25         S   NaN
# 2           1       1  female  38.0      1      0  71.2833         C     C
# 3           1       3  female  26.0      0      0    7.925         S   NaN
# 4           1       1  female  35.0      1      0     53.1         S     C
# ..        ...     ...     ...   ...    ...    ...      ...       ...   ...
# 887         0       2    male  27.0      0      0     13.0         S   NaN
# 888         1       1  female  19.0      0      0     30.0         S     B
# 889         0       3  female   NaN      1      2    23.45         S   NaN
# 890         1       1    male  26.0      0      0     30.0         C     C
# 891         0       3    male  32.0      0      0     7.75         Q   NaN
#
# [892 rows x 9 columns]

# %%
pd.read_csv('titanic.csv', names=['alive', 'class', 'gender', 'age', 'sibsp', 'parch', 'price', 'emb', 'deck'])
# Out:
#         alive   class  gender   age  sibsp  parch    price       emb  deck
# 0    survived  pclass     sex   age  sibsp  parch     fare  embarked  deck
# 1           0       3    male  22.0      1      0     7.25         S   NaN
# 2           1       1  female  38.0      1      0  71.2833         C     C
# 3           1       3  female  26.0      0      0    7.925         S   NaN
# 4           1       1  female  35.0      1      0     53.1         S     C
# ..        ...     ...     ...   ...    ...    ...      ...       ...   ...
# 887         0       2    male  27.0      0      0     13.0         S   NaN
# 888         1       1  female  19.0      0      0     30.0         S     B
# 889         0       3  female   NaN      1      2    23.45         S   NaN
# 890         1       1    male  26.0      0      0     30.0         C     C
# 891         0       3    male  32.0      0      0     7.75         Q   NaN
#
# [892 rows x 9 columns]

# %%
titanic = pd.read_csv('titanic.csv', usecols=['survived', 'pclass', 'sex', 'age'], index_col='pclass')

# %%
titanic.head()
# Out:
#         survived     sex   age
# pclass
# 3              0    male  22.0
# 1              1  female  38.0
# 3              1  female  26.0
# 1              1  female  35.0
# 3              0    male  35.0

# %%
titanic.columns=['alive', 'gender', 'age']

# %%
titanic.index.name = 'class'

# %%
titanic.head()
# Out:
#        alive  gender   age
# class
# 3          0    male  22.0
# 1          1  female  38.0
# 3          1  female  26.0
# 1          1  female  35.0
# 3          0    male  35.0

# %% [markdown]
# ## importing messy CSV files

# %%
pd.read_csv('titanic_raw.csv')
# Out:
#                                               This       is       the  \
# It   contains  all       passengers  that     were   aboard       the
# the  tragic    disaster  occured     in        the     year        19
# 0   0         3         male        22.0         1        0     $7.25
# 1   1         1         female      38.0         1        0  $71.2833
# 2   1         3         female      26.0         0        0    $7.925
# ...                                            ...      ...       ...
# 891 0         2         male        24.0         0        0     $10.5
# 892 0         3         male        34.0         1        1     $14.4
# 893 0         3         male        36.0         0        0   $7.8958
# End  of        the       Dataset                                  NaN
# Get  more      Datasets  on          Kaggle      .      com       NaN
#
#                                               Titanic  Dataset.
# ...

# %%
col_names = ['Survived', 'Class', 'Gender', 'Age', 'SibSip', 'ParCh', 'Fare', 'Emb', 'Deck']

# %%
titanic = pd.read_csv('titanic_raw.csv', skiprows=3, skipfooter=2, header=None, names=col_names)
# Out:
# C:\Users\drudi\Anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
titanic
# Out:
#     Survived  Class  Gender   Age  SibSip  ParCh      Fare Emb Deck
# 0          0      3    male  22.0       1      0     $7.25   S  NaN
# 1          1      1  female  38.0       1      0  $71.2833   C    C
# 2          1      3  female  26.0       0      0    $7.925   S  NaN
# 3          1      1  female  35.0       1      0     $53.1   S    C
# 4          0      3    male  35.0       0      0     $8.05   S  NaN
# ..       ...    ...     ...   ...     ...    ...       ...  ..  ...
# 889        1      1    male  26.0       0      0     $30.0   C    C
# 890        0      3    male  32.0       0      0     $7.75   Q  NaN
# 891        0      2    male  24.0       0      0     $10.5   S  NaN
# 892        0      3    male  34.0       1      1     $14.4   S  NaN
# 893        0      3    male  36.0       0      0   $7.8958   S  NaN
#
# [894 rows x 9 columns]

# %%
titanic.to_csv('titanic_imp.csv', index=False)

# %%
pd.read_csv('titanic_imp.csv')
# Out:
#     Survived  Class  Gender   Age  SibSip  ParCh      Fare Emb Deck
# 0          0      3    male  22.0       1      0     $7.25   S  NaN
# 1          1      1  female  38.0       1      0  $71.2833   C    C
# 2          1      3  female  26.0       0      0    $7.925   S  NaN
# 3          1      1  female  35.0       1      0     $53.1   S    C
# 4          0      3    male  35.0       0      0     $8.05   S  NaN
# ..       ...    ...     ...   ...     ...    ...       ...  ..  ...
# 889        1      1    male  26.0       0      0     $30.0   C    C
# 890        0      3    male  32.0       0      0     $7.75   Q  NaN
# 891        0      2    male  24.0       0      0     $10.5   S  NaN
# 892        0      3    male  34.0       1      1     $14.4   S  NaN
# 893        0      3    male  36.0       0      0   $7.8958   S  NaN
#
# [894 rows x 9 columns]

# %% [markdown]
# ## importing from excel files with pd.read_excel()

# %%
sales = pd.read_excel('sales.xls', index_col=0)

# %%
sales
# Out:
#             City Country  Sales  Bonus
# Mike    New York     USA     25   2.50
# Jim       Boston     USA     43   4.30
# Steven    London      UK     76   7.60
# Joe       Madrid   Spain     12   1.80
# Tom        Paris  France     89  13.35

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Mike to Tom
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     5 non-null      object
#  1   Country  5 non-null      object
#  2   Sales    5 non-null      int64
#  3   Bonus    5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
sales = pd.read_excel('sales.xls', index_col=0, header=0)

# %%
sales
# Out:
#             City Country  Sales  Bonus
# Mike    New York     USA     25   2.50
# Jim       Boston     USA     43   4.30
# Steven    London      UK     76   7.60
# Joe       Madrid   Spain     12   1.80
# Tom        Paris  France     89  13.35

# %%
sales = pd.read_excel('sales.xls', index_col=0, header=0, names=['Name', 'Loc_city', 'Loc_country', 'Revenue', 'Add_comp'])

# %%
sales
# Out:
#         Loc_city Loc_country  Revenue  Add_comp
# Name
# Mike    New York         USA       25      2.50
# Jim       Boston         USA       43      4.30
# Steven    London          UK       76      7.60
# Joe       Madrid       Spain       12      1.80
# Tom        Paris      France       89     13.35

# %%
pd.read_excel('sales.xls', index_col=0, usecols='A:C')
# Out:
#             City Country
# Mike    New York     USA
# Jim       Boston     USA
# Steven    London      UK
# Joe       Madrid   Spain
# Tom        Paris  France

# %%
pd.read_excel('sales.xls', index_col=0, usecols='C:E')
# Out:
#          Sales  Bonus
# Country
# USA         25   2.50
# USA         43   4.30
# UK          76   7.60
# Spain       12   1.80
# France      89  13.35

# %%
pd.read_excel('sales.xls', index_col=0, usecols='A, C:E')
# Out:
#        Country  Sales  Bonus
# Mike       USA     25   2.50
# Jim        USA     43   4.30
# Steven      UK     76   7.60
# Joe      Spain     12   1.80
# Tom     France     89  13.35

# %%
pd.read_excel('sales.xls', index_col=0, usecols=':C')
# Out:
#             City Country
# Mike    New York     USA
# Jim       Boston     USA
# Steven    London      UK
# Joe       Madrid   Spain
# Tom        Paris  France

# %%
pd.read_excel('sales.xls', index_col=0, usecols='C:')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-7392f73895e6> in <module>
# ----> 1 pd.read_excel('sales.xls', index_col=0, usecols='C:')
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     332         skipfooter=skipfooter,
# ...

# %%
pd.read_excel('sales.xls', index_col=0, usecols=[0, 3, 4])
# Out:
#         Sales  Bonus
# Mike       25   2.50
# Jim        43   4.30
# Steven     76   7.60
# Joe        12   1.80
# Tom        89  13.35

# %%
pd.read_excel('sales.xls', index_col=0, usecols=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-cf6844ec0982> in <module>
# ----> 1 pd.read_excel('sales.xls', index_col=0, usecols=2)
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     332         skipfooter=skipfooter,
# ...

# %%
pd.read_excel('sales.xls', index_col=0, usecols=['City', 'Sales'])
# Out:
#           Sales
# City
# New York     25
# Boston       43
# London       76
# Madrid       12
# Paris        89

# %% [markdown]
# ## customizing import with pd.read_excel()

# %%
pd.read_excel('summer_raw.xls')
# Out:
#   Unnamed: 0      City Country  Sales  Bonus
# 0       Mike  New York     USA     25    2.5
# 1        Jim    Boston     USA     43    4.3
# 2     Steven    London      UK     76    7.6
# 3        Joe    Madrid   Spain     12    1.8
# 4        Tom     Paris  France     89   13.4

# %%
pd.read_excel('summer_raw.xls', sheet_name='summer')
# Out:
#        Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0             NaN         NaN         NaN        NaN        NaN        NaN
# 1             NaN         NaN         NaN       Year       City      Sport
# 2             NaN         NaN         0.0       1896     Athens   Aquatics
# 3             NaN         NaN         1.0       1896     Athens   Aquatics
# 4             NaN         NaN         2.0       1896     Athens   Aquatics
# ...           ...         ...         ...        ...        ...        ...
# 31167         NaN         NaN     31165.0       2012     London  Wrestling
# 31168         NaN         NaN     31166.0       2012     London  Wrestling
# 31169         NaN         NaN     31167.0       2012     London  Wrestling
# 31170         NaN         NaN     31168.0       2012     London  Wrestling
# 31171         NaN         NaN     31169.0       2012     London  Wrestling
#
# ...

# %%
pd.read_excel('summer_raw.xls', sheet_name='summer', skiprows=[0,1])
# Out:
#        Unnamed: 0  Unnamed: 1  Unnamed: 2  Year    City      Sport  \
# 0             NaN         NaN           0  1896  Athens   Aquatics
# 1             NaN         NaN           1  1896  Athens   Aquatics
# 2             NaN         NaN           2  1896  Athens   Aquatics
# 3             NaN         NaN           3  1896  Athens   Aquatics
# 4             NaN         NaN           4  1896  Athens   Aquatics
# ...           ...         ...         ...   ...     ...        ...
# 31165         NaN         NaN       31165  2012  London  Wrestling
# 31166         NaN         NaN       31166  2012  London  Wrestling
# 31167         NaN         NaN       31167  2012  London  Wrestling
# 31168         NaN         NaN       31168  2012  London  Wrestling
# 31169         NaN         NaN       31169  2012  London  Wrestling
#
#                 Discipline                 Athlete Name Country Gender  \
# 0                 Swimming               HAJOS, Alfred      HUN    Men
# ...

# %%
pd.read_excel('summer_raw.xls', sheet_name='summer', skiprows=2, usecols='D:L')
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31165  2012  London  Wrestling  Wrestling Freestyle
# 31166  2012  London  Wrestling  Wrestling Freestyle
# 31167  2012  London  Wrestling  Wrestling Freestyle
# 31168  2012  London  Wrestling  Wrestling Freestyle
# 31169  2012  London  Wrestling  Wrestling Freestyle
#
#                       Athlete Name Country Gender                       Event  \
# 0                   HAJOS, Alfred      HUN    Men              100M Freestyle
# 1                HERSCHMANN, Otto      AUT    Men              100M Freestyle
# 2               DRIVAS, Dimitrios      GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer = pd.read_excel('summer_raw.xls', sheet_name='summer', skiprows=2, usecols='D:L')

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31165  2012  London  Wrestling  Wrestling Freestyle
# 31166  2012  London  Wrestling  Wrestling Freestyle
# 31167  2012  London  Wrestling  Wrestling Freestyle
# 31168  2012  London  Wrestling  Wrestling Freestyle
# 31169  2012  London  Wrestling  Wrestling Freestyle
#
#                       Athlete Name Country Gender                       Event  \
# 0                   HAJOS, Alfred      HUN    Men              100M Freestyle
# 1                HERSCHMANN, Otto      AUT    Men              100M Freestyle
# 2               DRIVAS, Dimitrios      GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31170 entries, 0 to 31169
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          31170 non-null  int64
#  1   City          31170 non-null  object
#  2   Sport         31170 non-null  object
#  3   Discipline    31170 non-null  object
#  4   Athlete Name  31170 non-null  object
#  5   Country       31166 non-null  object
#  6   Gender        31170 non-null  object
#  7   Event         31170 non-null  object
#  8   Medal         31170 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.to_csv('summer_imp.csv', index=False)

# %%
pd.read_csv('summer_imp.csv')
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31165  2012  London  Wrestling  Wrestling Freestyle
# 31166  2012  London  Wrestling  Wrestling Freestyle
# 31167  2012  London  Wrestling  Wrestling Freestyle
# 31168  2012  London  Wrestling  Wrestling Freestyle
# 31169  2012  London  Wrestling  Wrestling Freestyle
#
#                       Athlete Name Country Gender                       Event  \
# 0                   HAJOS, Alfred      HUN    Men              100M Freestyle
# 1                HERSCHMANN, Otto      AUT    Men              100M Freestyle
# 2               DRIVAS, Dimitrios      GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# ## importing data from the web with pd.read_html()

# %%
url = 'https://en.wikipedia.org/wiki/1976_Summer_Olympics_medal_table'

# %%
pd.read_html(url)
# Out:
# [                Rank                        NOC  Gold  Silver  Bronze  Total
#  0                  1         Soviet Union (URS)    49      41      35    125
#  1                  2         East Germany (GDR)    40      25      25     90
#  2                  3        United States (USA)    34      35      25     94
#  3                  4         West Germany (FRG)    10      12      17     39
#  4                  5                Japan (JPN)     9       6      10     25
#  5                  6               Poland (POL)     7       6      13     26
#  6                  7             Bulgaria (BUL)     6       9       7     22
#  7                  8                 Cuba (CUB)     6       4       3     13
#  8                  9              Romania (ROU)     4       9      14     27
#  9                 10              Hungary (HUN)     4       5      13     22
#  10                11              Finland (FIN)     4       2       0      6
# ...

# %%
type(pd.read_html(url))
# Out:
# list

# %%
len(pd.read_html(url))
# Out:
# 3

# %%
pd.read_html(url)[0]
# Out:
#                 Rank                        NOC  Gold  Silver  Bronze  Total
# 0                  1         Soviet Union (URS)    49      41      35    125
# 1                  2         East Germany (GDR)    40      25      25     90
# 2                  3        United States (USA)    34      35      25     94
# 3                  4         West Germany (FRG)    10      12      17     39
# 4                  5                Japan (JPN)     9       6      10     25
# 5                  6               Poland (POL)     7       6      13     26
# 6                  7             Bulgaria (BUL)     6       9       7     22
# 7                  8                 Cuba (CUB)     6       4       3     13
# 8                  9              Romania (ROU)     4       9      14     27
# 9                 10              Hungary (HUN)     4       5      13     22
# 10                11              Finland (FIN)     4       2       0      6
# ...

# %%
wik_1976 = pd.read_html(url)[0]

# %%
wik_1976.head()
# Out:
#   Rank                  NOC  Gold  Silver  Bronze  Total
# 0    1   Soviet Union (URS)    49      41      35    125
# 1    2   East Germany (GDR)    40      25      25     90
# 2    3  United States (USA)    34      35      25     94
# 3    4   West Germany (FRG)    10      12      17     39
# 4    5          Japan (JPN)     9       6      10     25

# %%
wik_1976.tail()
# Out:
#                 Rank                NOC  Gold  Silver  Bronze  Total
# 37                37      Bermuda (BER)     0       0       1      1
# 38                37     Pakistan (PAK)     0       0       1      1
# 39                37  Puerto Rico (PUR)     0       0       1      1
# 40                37     Thailand (THA)     0       0       1      1
# 41  Totals (41 NOCs)   Totals (41 NOCs)   198     199     216    613

# %%
wik_1976.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    42 non-null     object
#  1   NOC     42 non-null     object
#  2   Gold    42 non-null     int64
#  3   Silver  42 non-null     int64
#  4   Bronze  42 non-null     int64
#  5   Total   42 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 2.1+ KB

# %%
url2 = 'https://en.wikipedia.org/wiki/1996_Summer_Olympics_medal_table'

# %%
pd.read_html(url2)
# Out:
# [                                                   0
#  0                                Part of a series on
#  1  1996 Summer Olympics Bid process (bid details)...
#  2  .mw-parser-output .navbar{display:inline;font-...,
#                     Rank                Nation  Gold  Silver  Bronze  Total
#  0                     1  United States (USA)*    44      32      25    101
#  1                     2          Russia (RUS)    26      21      16     63
#  2                     3         Germany (GER)    20      18      27     65
#  3                     4           China (CHN)    16      22      12     50
#  4                     5          France (FRA)    15       7      15     37
#  ..                  ...                   ...   ...     ...     ...    ...
#  75                   71      Mozambique (MOZ)     0       0       1      1
#  76                   71     Puerto Rico (PUR)     0       0       1      1
# ...

# %%
len(pd.read_html(url2))
# Out:
# 4

# %%
pd.read_html(url2)[1]
# Out:
#                    Rank                Nation  Gold  Silver  Bronze  Total
# 0                     1  United States (USA)*    44      32      25    101
# 1                     2          Russia (RUS)    26      21      16     63
# 2                     3         Germany (GER)    20      18      27     65
# 3                     4           China (CHN)    16      22      12     50
# 4                     5          France (FRA)    15       7      15     37
# ..                  ...                   ...   ...     ...     ...    ...
# 75                   71      Mozambique (MOZ)     0       0       1      1
# 76                   71     Puerto Rico (PUR)     0       0       1      1
# 77                   71         Tunisia (TUN)     0       0       1      1
# 78                   71          Uganda (UGA)     0       0       1      1
# 79  Totals (79 nations)   Totals (79 nations)   271     273     298    842
#
# [80 rows x 6 columns]

# %%
wik_1996 = pd.read_html(url2)[1]

# %%
wik_1996
# Out:
#                    Rank                Nation  Gold  Silver  Bronze  Total
# 0                     1  United States (USA)*    44      32      25    101
# 1                     2          Russia (RUS)    26      21      16     63
# 2                     3         Germany (GER)    20      18      27     65
# 3                     4           China (CHN)    16      22      12     50
# 4                     5          France (FRA)    15       7      15     37
# ..                  ...                   ...   ...     ...     ...    ...
# 75                   71      Mozambique (MOZ)     0       0       1      1
# 76                   71     Puerto Rico (PUR)     0       0       1      1
# 77                   71         Tunisia (TUN)     0       0       1      1
# 78                   71          Uganda (UGA)     0       0       1      1
# 79  Totals (79 nations)   Totals (79 nations)   271     273     298    842
#
# [80 rows x 6 columns]

# %%
wik_1996.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    80 non-null     object
#  1   Nation  80 non-null     object
#  2   Gold    80 non-null     int64
#  3   Silver  80 non-null     int64
#  4   Bronze  80 non-null     int64
#  5   Total   80 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 3.9+ KB

# %%
wik_1996.to_csv('wik_1996.csv', index=False)
wik_1976.to_csv('wik_1976.csv', index=False)
